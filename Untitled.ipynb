# %%
print ("hello world")

# %%
f = open ('holamundo.txt','w')
f.write('hola mundo')
f.close()

# %%
pip install pdfminer

# %%
pip install pdfminer.six

# %%
# https://stackoverflow.com/questions/26494211/extracting-text-from-a-pdf-file-using-pdfminer-in-python
#116 ESC. PREST. HIP MARÍA-PILAR CHOCARRO UCAR
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

import glob
import re
import os

output_string = StringIO()
os.chdir("PDF/")
for file in glob.glob("*.pdf"):
    with open(file, 'rb') as in_file:
        parser = PDFParser(in_file)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()
        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)
        

print(output_string.getvalue())

# %%
from pathlib import Path

from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
from pdfminer.layout import LAParams, LTTextBox, LTTextLine
from pdfminer.converter import PDFPageAggregator

for path in Path("pdfs").glob("*.pdf"):
    with path.open("rb") as file:
        parser = PDFParser(file)
        document = PDFDocument(parser, "")
        if not document.is_extractable:
            continue

        manager = PDFResourceManager()
        params = LAParams()

        device = PDFPageAggregator(manager, laparams=params)
        interpreter = PDFPageInterpreter(manager, device)

        text = ""

        for page in PDFPage.create_pages(document):
            interpreter.process_page(page)
            for obj in device.get_result():
                if isinstance(obj, LTTextBox) or isinstance(obj, LTTextLine):
                    text += obj.get_text()
    with open("txts/{}.txt".format(path.stem), "w") as file:
        file.write(text)
#return 0

# %%
#https://stackoverflow.com/questions/67805746/loop-script-to-extract-multiple-pdfs-to-text-files-using-python-pdfminer

def main():

    from pathlib import Path

    from pdfminer.pdfparser import PDFParser
    from pdfminer.pdfdocument import PDFDocument
    from pdfminer.pdfpage import PDFPage
    from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
    from pdfminer.pdfdevice import PDFDevice
    from pdfminer.layout import LAParams, LTTextBox, LTTextLine
    from pdfminer.converter import PDFPageAggregator

    for path in Path("pdfs").glob("*.pdf"):
        with path.open("rb") as file:
            parser = PDFParser(file)
            document = PDFDocument(parser, "")
            if not document.is_extractable:
                continue

            manager = PDFResourceManager()
            params = LAParams()

            device = PDFPageAggregator(manager, laparams=params)
            interpreter = PDFPageInterpreter(manager, device)

            text = ""

            for page in PDFPage.create_pages(document):
                interpreter.process_page(page)
                for obj in device.get_result():
                    if isinstance(obj, LTTextBox) or isinstance(obj, LTTextLine):
                        text += obj.get_text()
        with open("txts/{}.txt".format(path.stem), "w") as file:
            file.write(text)
    return 0

# %%
import pdfplumber

filename = 'example.pdf'

if filename.endswith('.pdf'):
    all_text = '' # new line
    with pdfplumber.open(filename) as pdf:
        for pdf_page in pdf.pages:
            single_page_text = pdf_page.extract_text()
            # separate each page's text with newline
            all_text = all_text + '\n' + single_page_text
        print(all_text, file=open("output.txt", "a"))

# %%
import os
import pdfplumber
directory = (os.path.expanduser("/Users/beatrizbustos/Documents/MiNLP/PDF"))

#directory = (r"/Users/beatrizbustos/Documents/MiNLP/PDF")        
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('.pdf'):
        all_text = '' # new line
        with pdfplumber.open(file) as pdf:
            for pdf_page in pdf.pages:
               single_page_text = pdf_page.extract_text()
               # separate each page's text with newline
               all_text = all_text + '\n' + single_page_text
            print(all_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-179-13943bb79a26> in <module>
#       8     if filename.endswith('.pdf'):
#       9         all_text = '' # new line
# ---> 10         with pdfplumber.open(file) as pdf:
#      11             for pdf_page in pdf.pages:
#      12                single_page_text = pdf_page.extract_text()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pdfplumber/pdf.py in open(cls, path_or_fp, **kwargs)
#      53     def open(cls, path_or_fp, **kwargs):
#      54         if isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 55             fp = open(path_or_fp, "rb")
#      56             inst = cls(fp, **kwargs)
#      57             inst.close_file = fp.close
#
# FileNotFoundError: [Errno 2] No such file or directory: '27 ESC. SALVADOR MONTESINOS GARCIA.pdf'

# %%
import os


file_path = r'/Users/beatrizbustos/Documents/MiNLP/PDF/27 ESC. SALVADOR MONTESINOS GARCIA.pdf'
print( os.path.isfile(file_path))

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('.pdf'):
        all_text = '' # new line
        with pdfplumber.open(file) as pdf:
            # page = pdf.pages[0] - comment out or remove line
            # text = page.extract_text() - comment out or remove line
            for pdf_page in pdf.pages:
               single_page_text = pdf_page.extract_text()
               print( single_page_text )
               # separate each page's text with newline
               all_text = all_text + '\n' + single_page_text
            print(all_text)
            # print(text) - comment out or remove line
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-168-69e560639fc1> in <module>
#       3     if filename.endswith('.pdf'):
#       4         all_text = '' # new line
# ----> 5         with pdfplumber.open(file) as pdf:
#       6             # page = pdf.pages[0] - comment out or remove line
#       7             # text = page.extract_text() - comment out or remove line
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pdfplumber/pdf.py in open(cls, path_or_fp, **kwargs)
#      53     def open(cls, path_or_fp, **kwargs):
#      54         if isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 55             fp = open(path_or_fp, "rb")
#      56             inst = cls(fp, **kwargs)
#      57             inst.close_file = fp.close
#
# FileNotFoundError: [Errno 2] No such file or directory: '27 ESC. SALVADOR MONTESINOS GARCIA.pdf'

# %%
#https://stackoverflow.com/questions/62805973/how-do-i-extract-all-of-the-text-from-a-pdf-using-indexing
import os
import pdfplumber

directory = r'/Users/beatrizbustos/Documents/MiNLP/corpus_compraventa_ftp/cotejos_ftp_no_50/'

for filename in os.listdir(directory):
    print (filename)
    if filename.endswith('.pdf'):
        fullpath = os.path.join(directory, filename)
        #print(fullpath)
        all_text = ""
        with pdfplumber.open(fullpath) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                #print(text)
                all_text += '\n' + text
        print(all_text,file=open("cotejos_ftp_no_50.txt", "a"))
# Out:
# 1067 CV CASA COTEJO.pdf
# 28 COT RAMÓN CORRALES ANDREU.pdf
# 650 COT. MARÍA NOGALES SÁNCHEZ.pdf
# 552 COT. JOSÉ CORRAL MARTÍNEZ.pdf
# 2099 COT. ANA MARIA FORTUNY SUBIRATS.pdf
# 441 COT. JIMENA DEL CASTILLO RODRÍGUEZ.pdf
# 674 COT. LUIS FERNÁNDEZ-BRAVO FRANCÉS.pdf
# 1171 COT. MIGUEL ANGEL DEL POZO ESPADA.pdf
# 615 COT. JOSÉ MIGUEL MARZAL GAS.pdf
# 1081 COT. KOLDO MORENO BAQUEDANO.pdf
# 1738 COT INMUEBLES  JOSÉ CORRAL MARTÍNEZ.pdf
# 780 COT. FRANCISCO JOSÉ ROMÁN AYLLÓN.pdf
# 1974 COT. LUIS GASCH CABOT.pdf
# 413 COT. JOSE ANTONIO CARBONELL CRESPI.pdf
# 157 COT. MARÍA NOGALES SÁNCHEZ.pdf
# 461 COT. JOSE CORRAL MARTÍNEZ.pdf
# 1661 COT GONZALO CANO MORA.pdf
# 1530 COT. MANUEL MARIÑO VILA.pdf
# 1192 COT.MANUEL LORA-TAMAYO VILLACIEROS.pdf
# 2747 COT. AGUSTIN VERDERA SERVER.pdf
# 315 COT. RAÚL PÉREZ LANDETE.pdf
# 282 COT. SALVADOR MONTESINOS GARCIA.pdf
# 1290 COT. VICTOR MANUEL DE LUNA FANJUL.pdf
# 908 COT. MARIA DEL CARMEN VELA FERNÁNDEZ.pdf
# ...
